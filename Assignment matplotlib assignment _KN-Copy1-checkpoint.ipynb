# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# df= pd.read_excel(r'C:\Users\mebra.DESKTOP-L12LJA6\Thinkful Data Science Projects\titanic.xlsx')
# #print(df)

df=pd.read_csv('data/train.csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.groupby('Survived').PassengerId.count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
df.groupby('Survived').PassengerId.count().plot(kind='bar', color='blue', x='Survived', y='PassengerId')                                             
plt.title('Survival Rate')
plt.show()
# ??????? Why didnt show y label ????  --it's showing y as the count of records for survived vs not survived

# %%
##### The above figure shows survival passenger rate is less.

# %%
df.groupby('Survived').Age.mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
df.groupby('Survived').Age.mean().plot(kind='barh', color="green")
plt.title('Survival Average Age Rate')
plt.show()

# %%
##### The above figure shows average age of survived people is less than 30.

# %%
df.groupby('Sex').Survived.sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
df.groupby('Sex').Survived.sum().plot(kind='pie', title='Survival Rate by Sex')
#??????? How to add label and legend?????   

labels = [r'Organge Male', r'Blue Female']  
plt.legend(labels, loc="best") 
plt.show()

# %%
##### The above figure shows female Survival rate is more than male.

# %%
df.groupby(['Pclass','Sex']).Survived.sum()
# Out:
# Pclass  Sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: Survived, dtype: int64

# %%
df.groupby(['Pclass','Sex']).Survived.sum().plot(kind='bar', color='green')

# %%
##### The above figure shows distribution of male and female in different class.

# %%
df.groupby('Age').Survived.sum().plot(kind='line', color='red', title='Survival Age Range')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
##### The above figure shows survival age range of 20 to 40 years old are more than other age ranges.

# %%
#df.groupby('Pclass').Survived.count().plot(kind='scatter')
#plt.show
# ??????Why use kind: scatter gave me error?????????????? 
## there is no scatter with group by, as grouop by gives you aggregated data and scatter is not for that 
# you can do this instead 
df.plot(kind='scatter',x='Pclass',y='Age',color='red')
plt.show()

# %%
df.groupby('Pclass').Survived.sum().plot(kind='pie')
 #??????? how to label %value????? -- this is how 
labels = [ r'Blue Class 1', r'Organge Class 2', r'Green Class 3',]  
plt.legend(labels, loc="best") 

plt.show()

# %%
##### The above figure shows survival class range which shows passengers in class 1 survived more than others.

# %%
plt.plot(df['PassengerId'], color='purple')
plt.plot(df['Survived'], color='green')
plt.xlabel('PassengerId')
plt.ylabel('Survived')
plt.title('Survival Rate')
plt.show()
# ????How to describe the below figure???(im not sure choose correct column or not)?????
## this doesnt make sense as passenger ID is ID col and plotting that as a line doesnt make sense.

# %%
df.plot(kind='line', x='PassengerId', y='Age') # this tells you the age for each passenger ID

# %%
df.plot(kind='scatter', x='PassengerId', y='Age') # this tells you the age for each passenger ID

# %%
plt.scatter(
    x=df['Age'],
    y=df['Sex'],
    color='purple',
    marker='x', s=10
)
plt.show()

# %%
##### The above figure shows passenger base on sex and their age

# %%
df.plot(kind='scatter', x='Age',y= 'Pclass', color='red') #????????how to add tittle?????? --plt.title()
plt.title('Age vs Pclass')

#df.plot(kind='line')  #doesnt make sense as you are plotting all cols in df I would choose two cols 

df.plot(kind='line', x='PassengerId', y='Age') 

plt.show()

# %%
##### The first figure shows passenger's age  in different class
#???? second figure ????? #the original 2nd plot doesnt make sense as it's plotting all cols in lines 
#???? how to know we choose correct column?????   Shown above

# %%
df.Age.hist()

# %%
##### The above figure shows distribution of passenger's age

# %%
df.Survived.hist()

# %%
##### The above figure shows survival rate

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(df['Age'], color='purple')
plt.ylabel('Age')
plt.title('Age Rate')

plt.subplot(1, 2, 2)
plt.scatter(x = df['Sex'], y = df['Age'], color='green')
plt.ylabel('Survived')
plt.title('Survived Rate')

plt.tight_layout()
plt.show()

# %%
#### The above figures show passenger base on sex and their age

# %%
x=df.Age
plt.hist(x, bins=10, color='blue')
plt.title('Age Range')
plt.xlabel('Age')
plt.show()

# %%
##### The above figure shows number of people in each age bin

# %%
x=df.Age
y=df.Survived
plt.hist(x, density=True, color='blue', bins=np.arange(0, 100), alpha=.5) 
plt.hist(y, density=True, color='red', bins=np.arange(0, 100), alpha=.5)
plt.title('Normed histograms')
plt.xlabel('Age')
plt.show()

# %%
##### In the above figure,the blue figure shows passenger's age distribution and the red figure shows survival rate.

# %%
x=df.Fare
plt.boxplot(x)
plt.show()

# %%
##### The above figure shows spread of the fare value around the median fare.
