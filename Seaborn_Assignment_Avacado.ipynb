# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
avocado = pd.read_csv(r'C:\Users\mebra.DESKTOP-L12LJA6\Thinkful Data Science Projects\PythonThinkful\Avocado\avocado.csv')

# %%
avocado.head(4)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1           1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2           2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3           3   12/6/2015          1.08      78992.15  1132.00   71976.41
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany

# %%
#?? is it need to covert to dataframe?

# %%
##?? i use  AveragePrice as a continuse variable, im not sure is correct or not???

# %%
# Choose one variable and plot that variable four different ways.
# I choose AveragePrice as a continuous variable and displays in four different ways.
# First displays with hist:
plt.hist(avocado['AveragePrice'], color='red', alpha=.5, bins=6)
plt.title('Plot 1:Distribution of AveragePrice')
plt.show()

# %% [markdown]
# Shows distribution of AveragePrice which is high between 1 to 2.

# %%
# Second displays with line:
plt.plot(avocado['AveragePrice'])
plt.show()

# %% [markdown]
# Shows distribution of AveragePrice.

# %%
#Third displays with violinplot:
sns.violinplot(avocado['AveragePrice'], color='red')
plt.title('Plot 4:Distribution of AveragePrice')
plt.show()

# %% [markdown]
# Shows distribution of AveragePrice which shows mean of AveragePrice between 1 to 1.5$.

# %%
# Forth displays with boxplot:
sns.boxplot(avocado['AveragePrice'])
plt.title('Plot 3:Distribution of AveragePrice')
plt.show()

# %% [markdown]
# Shows distribution of AveragePrice which shows mean of AveragePrice between 1 to 1.5$.

# %% [markdown]
# ###??? im not sure about  analyzing correct??? and choosing correct plot ??
#
#
# Compare four different plot:
#
# The histplot shows distribution of AveragePrice which means the range sales between 1$ to 2$ more than other ranges but i think didn't provide more information about mean of AveragePrice.
#
# I think the lineplot shows useless information than histplot.(Ex:Distribution of different number of prices)
#
# I think the violinplot shows clear information. As you can see, it shows more clear distribution of AveragePrice and mean of AveragePrice.
#
# I think the boxplot  shows clear information too. As you can see, it shows more clear distribution of AveragePrice and mean of AveragePrice.
#
# I think boxplot shows more clear and useful information.

# %%
###???? i choose PLU 4046 and 4225 as a two continuous variables im not sure correct or not? 
##?? some plot took long time to show up ?? is it normal? why the reason???

# %%
# Choose two continuous variables, and plot them three different ways.
# I choose avocados PLU 4046 and 4225 sold as two continuous variables and displays in three different ways.
# First displays with histplot:
plt.hist(avocado['4046'], color='red', alpha=0.5, label='4046', bins=5)
plt.hist(avocado['4225'], color='blue', alpha=0.5, label='4225', bins=5)
plt.xlabel('Distribution of avocados sold')
plt.legend(loc='upper right')
plt.title('Plot 1: Compare Total number of avocados PLU 4046 and 4225 sold')
plt.show()

# %% [markdown]
# Shows distribution of 4046 and 4225  avocados sold which avocado's PLU 4046 sold a bit more distributed between 0 to 0.5 that means avocado's PLU 4046 sold a bit less than avocado's PLU 4225.

# %%
# Second displays with lineplot:
avocado.plot(kind='line', x='4046', y='4225', title='Plot 2:Compare Total number of avocados PLU 4046 and 4225 sold') 
plt.show()

# %% [markdown]
# Shows distribution of 4046 and 4225  avocados sold.

# %%
# Third displays with scatterplot:
sns.set(style='white')
g = sns.lmplot(x='4046', y='4225', data=avocado, fit_reg=False, scatter_kws={'alpha':0.5}, height=6) 
g.set_xlabels("4046")
g.set_ylabels("4225")
plt.title('Plot 3: Scatterplot: Compare Total number of avocados PLU 4046 and 4225 sold')
plt.show()
g = sns.lmplot(x='4046', y='4225', data=avocado, fit_reg=True, scatter_kws={'alpha':0.5}, height=6)
g.set_xlabels("4046")
g.set_ylabels("4225")
plt.title('Plot 3:Scatterplot with regression line: Compare Total number of avocados PLU 4046 and 4225 sold')
plt.show()

# %% [markdown]
# Scatterplot  shows more clear information. It shows more clear distribution of avocados sold in both and they have direct relationship which means if avocado's PLU 4046 sold more the avocado's PLU 4225 sold more too.

# %% [markdown]
# ###??? im not sure about  analyzing correct??? and choosing correct plot ??
#
# Compare three different plot:
#
# The histplot shows distribution of 4046 and 4225  avocados sold which avocado's PLU 4046 sold a bit more distributed between 0 to 0.5 that means avocado's PLU 4046 sold a bit less than avocado's PLU 4225, but i think didn't provide enough information.
#
# I think the lineplot didn't shows clear information too.
#
# I think the scatterplot  shows more clear information. As you can see, it shows more clear distribution of avocados sold and both have direct relationship which means if avocado's PLU 4046 sold more the avocado's PLU 4225 sold more too.
#
# I think scatterplot shows more clear and useful information.

# %%
###???? i choose Total Volume as a continuous variables and type as a categorical, im not sure correct or not? 
##?? some plot took long time to show up ?? is it normal? why the reason???

# %%
# Choose one continuous variable and one categorical variable, and plot them six different ways.
# I choose Total Volume as a continuous variable and type as a categorical variable.
# First displays with lineplot:
avocado.plot(kind='line', x='type', y='Total Volume',title='Plot 1:Distribution of Total Number of Avocados Sold by type') 
plt.xlabel('type')
plt.ylabel('Total Volume')
plt.show()

# %% [markdown]
# The lineplot shows the higher value of total number of avocados sold is conventional type.

# %%
# Second displays with scatterplot:
ax=plt.scatter(x='Total Volume', y='type', data= avocado)
plt.title('Plot 2:Distribution of Total Number of Avocados Sold by type')
plt.xlabel="Total Volume"
plt.ylabel="Type"
plt.show()

# %% [markdown]
# The scatterplot shows the higher value of total number of avocados sold is conventional type.

# %%
# Third displays with strip pointplot:
sns.set(style='whitegrid')
ax=sns.pointplot(x='Total Volume', y='type', data= avocado, kind='strip', dodge=True, join=False, ci=95)
plt.title('Plot 3:Distribution of Total Number of Avocados Sold by type')
ax.set(xlabel="", ylabel='Type')
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# The stripplot shows the higher value of total number of avocados sold is conventional type.

# %%
# Forth displays with barplot:
sns.set(style='darkgrid')
ax=sns.catplot(x='Total Volume', y='type', data= avocado, kind="bar")
plt.title('Plot 4:Distribution of Total Number of Avocados Sold by type')
ax.set(xlabel="", ylabel='Type')
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# The bar catplot shows the higher value of total number of avocados sold is conventional type.

# %%
# Fifth displays with violinplot:
sns.violinplot(x="type", y="Total Volume", data=avocado)
plt.title('Plot 5:Distribution of Total Number of Avocados Sold by type')
plt.show()

# %% [markdown]
# The boxplot shows the higher value of total number of avocados sold is conventional type.

# %%
# Six displays with boxplot:
sns.set(style='whitegrid')
ax=sns.boxplot(x='Total Volume', y='type', data= avocado)
plt.title('Plot 6:Distribution of Total Number of Avocados Sold by type')
ax.set(xlabel="", ylabel='Type')
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# The violinplot shows the higher value of total number of avocados sold is conventional type.

# %% [markdown]
# ###??? im not sure about  analyzing correct??? and choosing correct plot ??
#
#
#
# Compare six different plot:
#
# The lineplot shows distribution of total number of avocados sold by type which shows the value of total number of avocados sold in conventional type is more higher than organic type, but i think this plot not enough clear information.
#
# I think the scatterplot shows more clear than lineplot, but didn't shows clear information.
#
# I think the stripplot didn't shows clear information too.
#
# I think the barplot shows more clear than above three plots.
#
# I think the violinplot shows more clear plot too.
#
# I think the boxplot shows more clear and useful information, and we can see distribution range and some outlier too.
#
# I think the barplot and violinplot and boxplot show more clear and useful information.

# %%
###???? i choose AveragePrice,Total Volume, PLU 4046 and 4225 as a four continuous variables and type as a categoricalvariable
##?? im not sure correct or not???
##?? and use different plot but took long time and didnt show up ???
#????Also i didnt know about Probability distributions
# ???Bivariate relationships
# ???Whether the distributions or the relationships vary across groups
# ????Accompany your plot with a written description of what you see.
#?? could you please show me how to do it???

# %%
# Find a dataset with at least four continuous variables and one categorical variable.
# Create one master plot that gives insight into the variables and their interrelationships, including:
# Probability distributions
# Bivariate relationships
# Whether the distributions or the relationships vary across groups
# Accompany your plot with a written description of what you see.
# I choose AveragePrice,Total Volume,avocado PLU 4046,avocado PLU 4225 as a continuous variables,type as a categorical variable.
g = sns.lmplot(data=avocado,x='AveragePrice', y='Total Volume', row='4046', col='4225', hue='type', fit_reg=True, ci=False,
               scatter_kws={'alpha':0.4})
g.set_xlabels("AveragePrice")
g.set_ylabels("Total Volume")
plt.title('Scatterplot Regression: Meal Tips by Total Bill, split by gender and time')
plt.show()
